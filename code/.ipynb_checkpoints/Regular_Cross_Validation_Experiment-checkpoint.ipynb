# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import mlab
from random import sample
import math
import pickle as pk
from collections import Counter
from datetime import datetime
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from random import sample
from sklearn.model_selection import KFold
import numpy as np
from sklearn.metrics import roc_auc_score, precision_score
from sklearn.metrics import plot_roc_curve

# %%
from nltk.stem.snowball import SnowballStemmer
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import GaussianNB, MultinomialNB

# %% [markdown]
# ### load features

# %%
feature_path = '../data/feature'
featset_dict = {'pnp': 'pnp_feature.txt', 
                'bk': 'bk_feature.txt',
                'wh': 'wh_feature.txt'}

# %%
# load features to use
feat_list = ['label']
for f in os.listdir(feature_path):
    fp_feature_name = os.path.join(feature_path, f)
    with open(fp_feature_name, 'r') as fr:
        feature_names = [line.strip() for line in fr if not line.startswith("#")]
    feat_list += feature_names
    print(f"load {len(feature_names)} features")
# Out:
# load 5 features
# load 26 features
# load 23 features

# %%
def cv_exp_perform(feature_arr, label_arr, clf, f_res):
#     feature_arr = df.drop(['label'], axis=1).values
#     label_arr = df['label'].values

    k_fold = KFold(10, shuffle=True)

#     n_feature = int(feature_arr.shape[1])
#     max_depth = int(n_feature * max_depth_x)

#     clf = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, random_state=123)

    res_pre_list = []
    res_label_list = []

    print('cv start')
    # perform 10-fold cv
    for k, (train_idx, test_idx) in enumerate(k_fold.split(label_arr)):
        train_x, train_y = feature_arr[train_idx], label_arr[train_idx]
        test_x, test_y = feature_arr[test_idx], label_arr[test_idx]

        clf.fit(train_x, train_y)
        res_pre_list.append(clf.predict_proba(test_x)[:,1])
        res_label_list.append(test_y)

    # combine result
    pre_res = np.concatenate(res_pre_list)
    label_arr_res = np.concatenate(res_label_list)
    auc = roc_auc_score(label_arr_res, pre_res)
    print(f'auc : {auc}')
    
    fpr_roc, tpr_roc, thresh = metrics.roc_curve(label_arr_res, pre_res)
    fpr_roc_100 = fpr_roc * 100
    tpr_roc_100 = tpr_roc * 100
    
    i_1, = np.where(fpr_roc_100>=1.0)
    y_1 = tpr_roc_100[i_1[0]]
    operating_point = thresh[i_1[0]]
    
    roc_res_dict = {
            "fpr_100": fpr_roc_100,
            "tpr_100": tpr_roc_100,
            "auc": auc,
            "i_1": i_1,
            "y_1": y_1,
            "thresh": thresh,
            'o_point': operating_point
            }

    with open(f_res, 'wb') as f:
        pk.dump(roc_res_dict, f)
    return auc, y_1, operating_point

# %% [markdown]
# ### regular cross validation exp with taser

# %%
# load dataset
f_tr = '../data/TSS_TA_training_data.csv'
df = pd.read_csv(f_tr, usecols=feat_list)
df.shape
# Out:
# (1500, 55)

# %%
df.head()
# Out:
#   label  n_bk_dom  n_blog_dom  n_forum_dom  ptile95_contain_hp  \
# 0     Y        10           0            0               19.75
# 1     Y         9           0            0               23.50
# 2     Y       312         158           21               12.75
# 3     Y        55           8           13                3.25
# 4     Y         7           0            0                6.00
#
#    mean_contain_hp  med_contain_hp  n_follow_url  n_nofollow_url  \
# 0           8.1667             5.5             6               9
# 1           6.6250             2.0             2               9
# 2          15.6195             8.0          1928             243
# 3           2.0000             1.0           171             100
# 4           4.0000             4.0             2               7
#
#    r_follow_url  ...  pds_fp_size_w_pct_mean  pds_vp_area_ratio_mean  \
# 0        0.4000  ...                  0.7086                  0.0073
# ...

# %%
df['label'] = df['label'].apply(lambda x: 1 if x=='Y' else 0)

# %%
f_res = '../result/exp_res_pkl/taser_regular_cv_result.pkl'

# %%
def taser_regular_cv(df, f_res, max_depth_x=1, n_estimators = 500):
    feature_arr = df.drop(['label'], axis=1).values
    label_arr = df['label'].values

    n_feature = int(feature_arr.shape[1])
    max_depth = int(n_feature * max_depth_x)
    clf = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, random_state=123)

    return cv_exp_perform(feature_arr, label_arr, clf, f_res)

# %%
# def taser_cv_exp_perform(df, f_res, max_depth_x=1, n_estimators = 500):
#     feature_arr = df.drop(['label'], axis=1).values
#     label_arr = df['label'].values

#     k_fold = KFold(10, shuffle=True)

#     n_feature = int(feature_arr.shape[1])
#     max_depth = int(n_feature * max_depth_x)

#     clf = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth, random_state=123)

#     res_pre_list = []
#     res_label_list = []

#     print('cv start')
#     # perform 10-fold cv
#     for k, (train_idx, test_idx) in enumerate(k_fold.split(label_arr)):
#         train_x, train_y = feature_arr[train_idx], label_arr[train_idx]
#         test_x, test_y = feature_arr[test_idx], label_arr[test_idx]

#         clf.fit(train_x, train_y)
#         res_pre_list.append(clf.predict_proba(test_x)[:,1])
#         res_label_list.append(test_y)

#     # combine result
#     pre_res = np.concatenate(res_pre_list)
#     label_arr_res = np.concatenate(res_label_list)
#     auc = roc_auc_score(label_arr_res, pre_res)
#     print(f'auc : {auc}')
    
#     fpr_roc, tpr_roc, thresh = metrics.roc_curve(label_arr_res, pre_res)
#     fpr_roc_100 = fpr_roc * 100
#     tpr_roc_100 = tpr_roc * 100
    
#     i_1, = np.where(fpr_roc_100>=1.0)
#     y_1 = tpr_roc_100[i_1[0]]
#     operating_point = thresh[i_1[0]]
    
#     roc_res_dict = {
#             "fpr_100": fpr_roc_100,
#             "tpr_100": tpr_roc_100,
#             "auc": auc,
#             "i_1": i_1,
#             "y_1": y_1,
#             "thresh": thresh,
#             'o_point': operating_point
#             }

#     with open(f_res, 'wb') as f:
#         pk.dump(roc_res_dict, f)
#     return auc, y_1, operating_point

# %%
auc, y_1, op = taser_cv_exp_perform(df, f_res, max_depth_x=1, n_estimators = 500)
# Out:
# cv start
# auc : 0.993619

# %%
y_1, op
# Out:
# (92.4, 0.546)

# %% [markdown]
# ### regular cross validation exp with text based model

# %%
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]

    stem_doc = " ".join(stems)
    return stem_doc

# %%
def text_model_regular_cv(df, f_res, f_v_map):
    # Initialise the count vectorizer with the English stop words
    count_vectorizer = CountVectorizer(stop_words='english', 
                                       max_df=0.8, 
                                       max_features=10000,
                                       min_df=0.08,
                                       ngram_range=(1,3))
    
    # Fit and transform the processed titles
    count_data = count_vectorizer.fit_transform(df['text_processed'])
    count_data = count_data.toarray()
    
    # save vocabulary map for future test's usage
#     fp_token = os.path.join(res_path, 'nb_clf_vocabulary_map.pkl')
    with open(f_v_map, 'wb') as f:
        pk.dump(count_vectorizer.vocabulary_, f)

    label_arr = df['label'].values
    clf = MultinomialNB()
    return cv_exp_perform(count_data, label_arr, clf, f_res)

# %%
# def text_model_cv_exp_perform(df, res_path):
#     # Initialise the count vectorizer with the English stop words
#     count_vectorizer = CountVectorizer(stop_words='english', 
#                                        max_df=0.8, 
#                                        max_features=10000,
#                                        min_df=0.08,
#                                        ngram_range=(1,3))
    
#     # Fit and transform the processed titles
#     count_data = count_vectorizer.fit_transform(df['text_processed'])
#     count_data = count_data.toarray()
    
#     # save vocabulary map for future test's usage
#     fp_token = os.path.join(res_path, 'nb_clf_vocabulary_map.pkl')
#     with open(fp_token, 'wb') as f:
#         pk.dump(count_vectorizer.vocabulary_, f)
    
#     label_list = df['label'].tolist()
#     label_arr = df['label'].values
#     clf = MultinomialNB()
    
#     # cv experiment perform
#     k_fold = KFold(10, shuffle=True)
#     res_pre_list = []
#     res_label_list = []

#     print('cv start')
#     for k, (train_idx, test_idx) in enumerate(k_fold.split(label_list)):
#         train_x, train_y = count_data[train_idx], label_arr[train_idx]
#         test_x, test_y = count_data[test_idx], label_arr[test_idx]

#         clf.fit(train_x, train_y)
#         y_pre_prob = clf.predict_proba(test_x)[:,1]

#         res_pre_list.append(y_pre_prob)
#         res_label_list.append(test_y)

#     # combine result
#     pre_res = np.concatenate(res_pre_list)
#     label_arr_res = np.concatenate(res_label_list)
#     auc = roc_auc_score(label_arr_res, pre_res)
#     print(f"auc is : {auc}")

#     fpr_roc, tpr_roc, thresh = metrics.roc_curve(label_arr_res, pre_res)
#     fpr_roc_100 = fpr_roc * 100
#     tpr_roc_100 = tpr_roc * 100

#     i_1, = np.where(fpr_roc_100>=1.0)
#     y_1 = tpr_roc_100[i_1[0]-1]
#     operating_point = thresh[i_1[0]-1]

#     roc_res_dict = {
#                 "fpr_100": fpr_roc_100,
#                 "tpr_100": tpr_roc_100,
#                 "auc": auc,
#                 "i_1": i_1,
#                 "y_1": y_1,
#                 "thresh": thresh,
#                 'o_point': operating_point
#                 }
    
#     f_res = os.path.join(res_path, 'text_model_regular_cv_result.pkl')
#     with open(f_res, 'wb') as f:
#         pk.dump(roc_res_dict, f)
#     return auc, y_1, operating_point

# %%
# load text data
f_tr_txt = '../data/text_data_for_TSS_TA_training_set.csv'
df_txt = pd.read_csv(f_tr_txt)
df_txt.shape
# Out:
# (1500, 4)

# %%
df_txt.head()
# Out:
#                domain                                        concat_text  \
# 0  123-hp-printer.com  hp com setup hp officejet pro setup guid get e...
# 1   123-hp-support.co  hp com setup officejet pro softwar instal toll...
# 2      123-hpenvy.com  how to instal hp envi printer 123-hpenvi com s...
# 3  123.hpsetup.online  hp printer isn t print hp com setup hpsetup on...
# 4       123hp-com.com  hp officejet printer setup and instal sorri yo...
#
#    label                                     text_processed
# 0      1  hp com setup hp officejet pro setup guid get e...
# 1      1  hp com setup officejet pro softwar instal toll...
# 2      1  how to instal hp envi printer 123-hpenvi com s...
# 3      1  hp printer isn t print hp com setup hpsetup on...
# 4      1  hp officejet printer setup and instal sorri yo...

# %%
res_path = '../result/exp_res_pkl/text_model_regular_cv_result.pkl'
fp_token = '../result/exp_res_pkl/nb_clf_vocabulary_map.pkl'
auc, y_1, op = text_model_regular_cv(df_txt, res_path, fp_token)
# Out:
# cv start
# auc : 0.977978

# %% [markdown]
# ### topic generalization cv with taser

# %%
topic_map_path = '../data/topic_map/pos_topic_domain_map.pkl'
topic_map = pk.load(open(topic_map_path, 'rb'))

# %%
topic_map
# Out:
# {'5': ['customersupporthelpline.com',
#   'aoltech.supportphone-number.com',
#   'www.gmailinformation.com',
#   'www.itphonenumber.com',
#   'www.msofficesupportnumber.com',
#   'customer-helpnumber.ca',
#   'customer-numbercanada.com',
#   'getcustomerservices.com',
#   'www.impactpcsupport.com',
#   'www.instatechexperts.com',
#   'www.mail-customerservice.com',
#   'www.zeniusgroup.com',
#   'yahoo.supportnumbercanada.ca',
#   'technicalarmy.com',
#   'prostechsupport.com',
#   'email-customer-care.com',
#   'getemailservices.com',
#   'sbcglobalcustomerservice.over-blog.com',
#   'www.1800-phonenumber.com',
#   'www.247customerservicenumber.com',
#   'yahoo-mailsupport.com',
#   'onlinetechnicalhelp.over-blog.com',
#   'sbcglobal-email.contactsupporthelpnumber.com',
#   'www.global-technical-support.co.uk',
#   'www.helptechnumber.com',
#   'www.realmailfix.com',
#   'www.glstechserve.com',
#   'www.instohelp.com',
#   'www.pwsupportnumber.com',
# ...

# %%
def cv_perform(df_mix, exp_dom_list, topic_map, repeat_n = 3):
#     global n_estimators, max_depth

#     feature_x, label_y = self.exp_data_pre(df_mix)
#     n_row = int(feature_x.shape[0])
#     n_feature = int(feature_x.shape[1])
#     max_depth = int(n_feature * max_depth_x)

#     clf = self.rf_clf_construct(n_estimators, max_depth)
    tprs = []
    aucs = []
    threshs = []
#     mean_fpr = np.linspace(0, 1, 200)
#     fig, ax = plt.subplots()

    for t in topic_map.keys():
        # print(f"topic : {t}")
        dom_test_pos = topic_map[t]
        n_test_pos = len(dom_test_pos)

        dom_train_pos = set(dom_list_pos) - set(dom_test_pos)
        n_train_pos = len(dom_train_pos)

        y_test_list = []
        y_pre_list = []
        for i in range(repeat_n):
            dom_test_neg = sample(dom_list_neg, n_test_pos)
            dom_train_neg = sample(set(dom_list_neg) - set(dom_test_neg), n_train_pos*2)

            dom_train = set(dom_train_pos) | set(dom_train_neg)
            dom_test = set(dom_test_pos) | set(dom_test_neg)

            df_train = df_mix[df_mix['domain'].isin(dom_train)]
            df_test = df_mix[df_mix['domain'].isin(dom_test)]

            feature_train, label_train = exp_data_pre(df_train)
            feature_test, label_test = exp_data_pre(df_test)

            clf.fit(feature_train, label_train)

            y_pre_prob = clf.predict_proba(feature_test)[:,1]

            y_test_list.append(label_test)
            y_pre_list.append(y_pre_prob)


        y_test_array = np.concatenate(y_test_list)
        y_pre_array = np.concatenate(y_pre_list)

        fpr_t, tpr_t, thresh_t = metrics.roc_curve(y_test_array, y_pre_array)
        interp_tpr = np.interp(mean_fpr, fpr_t, tpr_t)
        interp_tpr[0] = 0.0
        tprs.append(interp_tpr)

        interp_thr = np.interp(mean_fpr, fpr_t, thresh_t)
        interp_thr[0] = 0.0
        threshs.append(interp_thr)

        auc_t = roc_auc_score(y_test_array, y_pre_array)
        auc_t = round(auc_t, 4)
        aucs.append(auc_t)
        # print(f"topinc {t} : auc -- {auc_t}")


    # plot mean ROC curve
    mean_tpr = np.mean(tprs, axis=0)
    mean_tpr[-1] = 1.0
    mean_auc = auc(mean_fpr, mean_tpr)
    std_auc = np.std(aucs)

    mean_fpr_100 = mean_fpr * 100
    mean_tpr_100 = mean_tpr * 100
    ax.plot(mean_fpr_100, mean_tpr_100, color='b',
            label=r'Mean ROC (AUC = %0.2f $\pm$ %0.2f)' % (mean_auc, std_auc),
            lw=2, alpha=.8)

    mean_thr = np.mean(threshs, axis=0)
    mean_tpr[-1] = 1.0


    i_1, = np.where(mean_fpr_100>=1.0)
    i_15, = np.where(mean_fpr_100>=1.5)

    y_1 = mean_tpr_100[i_1[0]]
    print(f"thresh : {mean_thr[i_1[0]]}, mean_tpr : {y_1}")
    y_1 = round(y_1, 1)

    y_15 = mean_tpr_100[i_15[0]]
    print(f"thresh : {mean_thr[i_15[0]]}, mean_tpr : {y_15}")
    y_15 = round(y_15, 1)

    ax.set_xticks([i_1], minor=True)

    ax.set_yticks([y_1], minor=True)
    ax.set_yticklabels([str(y_1)], minor=True)
    # ax.yaxis.grid(True, which='minor', linestyle='--', linewidth=1.5)

    plt.vlines(1, ymin=0, ymax=y_1, colors='black', linestyle='--', linewidth=1.5)
    plt.hlines(y_1, xmin=0, xmax=1, colors='black', linestyle='--', linewidth=1.5)

    plt.vlines(1.5, ymin=0, ymax=y_15, colors='black', linestyle='--', linewidth=1.5)
    plt.hlines(y_15, xmin=0, xmax=1.5, colors='black', linestyle='--', linewidth=1.5)

    ax.set(xlim=[0, 100], ylim=[-1, 100],
           title="Receiver operating characteristic of Topic-Agnostic CV experiment")
    ax.legend(loc="best", fontsize='large')

    # x_ticks = np.arange(0, 100, 1)
    # ax.set_xticks(x_ticks)

    ax.set_ylim([0,100])

    plt.xlabel('False Positive Rate (%,log scale)')
    plt.ylabel('True Positive Rate (%)')
    ax.set_xscale('symlog')
    # ax.grid(True)

    fp_fig = os.path.join(self.result_path, fig_name)
    plt.savefig(fp_fig, format='pdf', bbox_inches='tight')


    roc_res_dict = {
                "mean_fpr_100": mean_fpr_100,
                "mean_tpr_100": mean_tpr_100,
                "aucs": aucs,
                "mean_auc": mean_auc,
                "std_auc": std_auc,
                "i_1": i_1,
                "i_15": i_15,
                "y_1": y_1,
                "y_15": y_15,
                "threshs": threshs,
                "mean_thr": mean_thr
                }

    fp_roc = os.path.join(self.result_path, f'roc_data_result_{seq}.pkl')
    self.data_save_pkl(roc_res_dict, fp_roc)
